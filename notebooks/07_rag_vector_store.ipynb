# %% [markdown]
# # Initialisation

# %%
import pandas as pd
from src.backend.vector_store import build_vector_store

# %%
df_chunks = pd.read_csv("../data/processed/parcoursup_2026_enriched_chunks.csv")

# %% [markdown]
# # Test de la fonction

# %%
df_vs = build_vector_store(df_chunks)

# %%
df_vs.head()
# Out:
#   chunk_id  chunk_index                                         chunk_text  \
# 0      0_0            0  Nom de la formation : Formation d'ingénieur Ba...
# 1      0_1            1   présenter un projet.\nDisposer de compétences...
# 2      0_2            2  .\nLes diplômés Polytech exercent dans des sec...
# 3      1_0            0  Nom de la formation : Formation d'ingénieur Ba...
# 4      1_1            1  t présenter un projet.\nDisposer de compétence...
#
#                        type_formation type_etablissement commune  \
# 0  Formations des écoles d'ingénieurs            Publics   Dijon
# 1  Formations des écoles d'ingénieurs            Publics   Dijon
# 2  Formations des écoles d'ingénieurs            Publics   Dijon
# 3  Formations des écoles d'ingénieurs            Publics  Angers
# 4  Formations des écoles d'ingénieurs            Publics  Angers
#
#    is_apprentissage frais_scolarite  formation_selective  \
# 0                 0           628 €                  1.0
# 1                 0           628 €                  1.0
# 2                 0           628 €                  1.0
# 3                 0           628 €                  1.0
# 4                 0           628 €                  1.0
#
#    formation_ouverte_boursiers embedding
# 0                          1.0      None
# 1                          1.0      None
# 2                          1.0      None
# 3                          1.0      None
# 4                          1.0      None

# %%
df_vs.columns
# Out:
# Index(['chunk_id', 'chunk_index', 'chunk_text', 'type_formation',
#        'type_etablissement', 'commune', 'is_apprentissage', 'frais_scolarite',
#        'formation_selective', 'formation_ouverte_boursiers', 'embedding'],
#       dtype='object')
